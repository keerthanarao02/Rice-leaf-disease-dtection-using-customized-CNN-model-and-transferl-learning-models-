# %% [markdown]
# # ADAM OPTIMSER WITH DROPOUT

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Flatten
from keras. layers import MaxPooling2D
from keras.layers import Dense
import numpy as np
import tensorflow as tf
# @title

# %%
model=Sequential()
conv1=model.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
conv1=model.add(Conv2D(32,(3,3),input_shape=(64,64,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(units=128,activation='relu'))
model.add(Dense(3,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.4,horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set =train_datagen.flow_from_directory('/content/drive/MyDrive/archive/training set',target_size = (64, 64),batch_size = 8,class_mode = 'categorical')
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/archive/testing set',target_size = (64, 64))
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.

# %%
import matplotlib.pyplot as plt

# Assuming you have the class labels and their corresponding sample counts in dictionaries
# Example:
class_counts = {'Bacterial leaf blight': 68, 'Brown spot': 54, 'Leaf smut': 33}

# Prepare the data for the pie chart
labels = class_counts.keys()
counts = class_counts.values()

# Create the pie chart
plt.pie(counts, labels=labels, autopct='%1.1f%%')
plt.title('Training Data Distribution')

# Display the chart
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
type(training_set)
# Out:
# keras.preprocessing.image.DirectoryIterator

# %%
model.fit(training_set,steps_per_epoch = 10,epochs = 20)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 4s 279ms/step - loss: 1.7849 - accuracy: 0.4267
# Epoch 2/20
# 10/10 [==============================] - 2s 205ms/step - loss: 1.0832 - accuracy: 0.4267
# Epoch 3/20
# 10/10 [==============================] - 2s 240ms/step - loss: 1.0706 - accuracy: 0.4125
# Epoch 4/20
# 10/10 [==============================] - 3s 294ms/step - loss: 1.0274 - accuracy: 0.4625
# Epoch 5/20
# 10/10 [==============================] - 2s 223ms/step - loss: 0.9924 - accuracy: 0.4800
# Epoch 6/20
# 10/10 [==============================] - 2s 229ms/step - loss: 0.9638 - accuracy: 0.5125
# Epoch 7/20
# 10/10 [==============================] - 2s 209ms/step - loss: 0.8978 - accuracy: 0.6133
# Epoch 8/20
# 10/10 [==============================] - 2s 217ms/step - loss: 0.8836 - accuracy: 0.5875
# Epoch 9/20
# 10/10 [==============================] - 4s 376ms/step - loss: 0.8046 - accuracy: 0.6125
# Epoch 10/20
# ...

# %%
import numpy as np
from keras.preprocessing import image
import keras.utils as image
test_image =image.load_img('/content/drive/MyDrive/archive/testing set/Leaf smut/DSC_0702.jpg',target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(result)
res=result[0]
val=max(res)
ind = np.where(res == val)[0]
class_names = ['bacterial leaf blight','brown spot','leaf smut']  # Replace with your class names
predicted_class_name = class_names[int(ind)]
print(predicted_class_name)
# Out:
# 1/1 [==============================] - 0s 91ms/step
# [[0. 0. 1.]]
# leaf smut

# %%
import numpy as np
from keras.preprocessing import image
import keras.utils as image
test_image =image.load_img('/content/drive/MyDrive/archive/testing set/Brown spot/DSC_0325.jpg',target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(result)
res=result[0]
val=max(res)
ind = np.where(res == val)[0]
class_names = ['bacterial leaf blight','brown spot','leaf smut']  # Replace with your class names
predicted_class_name = class_names[int(ind)]
print(predicted_class_name)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# [[0. 1. 0.]]
# brown spot

# %%
import numpy as np
from keras.preprocessing import image
import keras.utils as image
test_image =image.load_img('/content/drive/MyDrive/archive/testing set/Bacterial leaf blight/DSC_0430.jpg',target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
print(result)
res=result[0]
val=max(res)
ind = np.where(res == val)[0]
class_names = ['bacterial leaf blight','brown spot','leaf smut']  # Replace with your class names
predicted_class_name = class_names[int(ind)]
print(predicted_class_name)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# [[1. 0. 0.]]
# bacterial leaf blight

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential

# Define the paths to the train and test directories
train_dir = '/content/drive/MyDrive/archive/training set'
test_dir = '/content/drive/MyDrive/archive/testing set'

# Set the image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 16

# Create an instance of the ImageDataGenerator for data augmentation and normalization
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   rotation_range=10,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# Load and preprocess the test data
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_width, img_height),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(train_generator.num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,steps_per_epoch=train_generator.samples // batch_size,epochs=10, validation_data=test_generator,
                    validation_steps=test_generator.samples // batch_size)
import matplotlib.pyplot as plt

# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.
# Epoch 1/10
# 9/9 [==============================] - 28s 3s/step - loss: 2.0635 - accuracy: 0.3817 - val_loss: 1.0968 - val_accuracy: 0.4688
# Epoch 2/10
# 9/9 [==============================] - 9s 1s/step - loss: 1.0948 - accuracy: 0.3588 - val_loss: 1.0710 - val_accuracy: 0.6250
# Epoch 3/10
# 9/9 [==============================] - 8s 875ms/step - loss: 1.0412 - accuracy: 0.4809 - val_loss: 1.0647 - val_accuracy: 0.5000
# Epoch 4/10
# 9/9 [==============================] - 9s 907ms/step - loss: 0.9895 - accuracy: 0.5038 - val_loss: 1.0037 - val_accuracy: 0.5000
# Epoch 5/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.9800 - accuracy: 0.6031 - val_loss: 1.0365 - val_accuracy: 0.4375
# Epoch 6/10
# 9/9 [==============================] - 9s 1s/step - loss: 0.9362 - accuracy: 0.5191 - val_loss: 1.0170 - val_accuracy: 0.5625
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Test'])
plt.show()

# %% [markdown]
# # **ADAM OPTIMIZER WITHOUT DROPOUT**

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
model_name = "MyCNNModel"
# Define the paths to the train and test directories
train_dir = '/content/drive/MyDrive/archive/training set'
test_dir = '/content/drive/MyDrive/archive/testing set'

# Set the image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 16

# Create an instance of the ImageDataGenerator for data augmentation and normalization
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   rotation_range=10,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# Load and preprocess the test data
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_width, img_height),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(train_generator.num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,steps_per_epoch=train_generator.samples // batch_size,epochs=10, validation_data=test_generator,
                    validation_steps=test_generator.samples // batch_size)
import matplotlib.pyplot as plt

# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.
# Epoch 1/10
# 9/9 [==============================] - 17s 1s/step - loss: 1.3203 - accuracy: 0.3969 - val_loss: 1.1268 - val_accuracy: 0.2812
# Epoch 2/10
# 9/9 [==============================] - 13s 1s/step - loss: 1.0495 - accuracy: 0.3740 - val_loss: 1.1283 - val_accuracy: 0.3750
# Epoch 3/10
# 9/9 [==============================] - 14s 2s/step - loss: 1.0177 - accuracy: 0.4122 - val_loss: 1.1794 - val_accuracy: 0.5312
# Epoch 4/10
# 9/9 [==============================] - 12s 1s/step - loss: 0.9353 - accuracy: 0.5191 - val_loss: 1.0605 - val_accuracy: 0.5312
# Epoch 5/10
# 9/9 [==============================] - 13s 1s/step - loss: 0.8679 - accuracy: 0.5802 - val_loss: 1.5005 - val_accuracy: 0.4375
# Epoch 6/10
# 9/9 [==============================] - 12s 1s/step - loss: 0.7611 - accuracy: 0.7023 - val_loss: 1.4979 - val_accuracy: 0.4375
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Test'])
plt.show()

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,shear_range = 0.2,zoom_range = 0.4,horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set =train_datagen.flow_from_directory('/content/drive/MyDrive/archive/training set',target_size = (64, 64),batch_size = 8,class_mode = 'categorical')
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/archive/testing set',target_size = (64, 64))
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.

# %% [markdown]
# # **ADADELTA WITH DROPOUT**

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt


# Define the paths to the train and test directories
train_dir = '/content/drive/MyDrive/archive/training set'
test_dir = '/content/drive/MyDrive/archive/testing set'

# Set the image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 16

# Create an instance of the ImageDataGenerator for data augmentation and normalization
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   rotation_range=10,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# Load and preprocess the test data
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_width, img_height),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(train_generator.num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adadelta',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,
                    steps_per_epoch=train_generator.samples // batch_size,
                    epochs=10,
                    validation_data=test_generator,
                    validation_steps=test_generator.samples // batch_size)

# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.
# Epoch 1/10
# 9/9 [==============================] - 114s 12s/step - loss: 1.1228 - accuracy: 0.2824 - val_loss: 1.0975 - val_accuracy: 0.4688
# Epoch 2/10
# 9/9 [==============================] - 15s 2s/step - loss: 1.1076 - accuracy: 0.3588 - val_loss: 1.0995 - val_accuracy: 0.4062
# Epoch 3/10
# 9/9 [==============================] - 15s 2s/step - loss: 1.1170 - accuracy: 0.3359 - val_loss: 1.0957 - val_accuracy: 0.4375
# Epoch 4/10
# 9/9 [==============================] - 15s 2s/step - loss: 1.0949 - accuracy: 0.3893 - val_loss: 1.0927 - val_accuracy: 0.4688
# Epoch 5/10
# 9/9 [==============================] - 14s 2s/step - loss: 1.0862 - accuracy: 0.3403 - val_loss: 1.0919 - val_accuracy: 0.3750
# Epoch 6/10
# 9/9 [==============================] - 14s 2s/step - loss: 1.0967 - accuracy: 0.3664 - val_loss: 1.1003 - val_accuracy: 0.3438
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Test'])
plt.show()

# %% [markdown]
# # ADADELTA WITHOUT DROPOUT

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt


# Define the paths to the train and test directories
train_dir = '/content/drive/MyDrive/archive/training set'
test_dir = '/content/drive/MyDrive/archive/testing set'

# Set the image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 16

# Create an instance of the ImageDataGenerator for data augmentation and normalization
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   rotation_range=10,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# Load and preprocess the test data
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_width, img_height),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(train_generator.num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adadelta',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,
                    steps_per_epoch=train_generator.samples // batch_size,
                    epochs=10,
                    validation_data=test_generator,
                    validation_steps=test_generator.samples // batch_size)

# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.
# Epoch 1/10
# 9/9 [==============================] - 16s 2s/step - loss: 1.0877 - accuracy: 0.3817 - val_loss: 1.0992 - val_accuracy: 0.2812
# Epoch 2/10
# 9/9 [==============================] - 15s 2s/step - loss: 1.0817 - accuracy: 0.4046 - val_loss: 1.0954 - val_accuracy: 0.2812
# Epoch 3/10
# 9/9 [==============================] - 14s 2s/step - loss: 1.0765 - accuracy: 0.4275 - val_loss: 1.0860 - val_accuracy: 0.3125
# Epoch 4/10
# 9/9 [==============================] - 13s 1s/step - loss: 1.0839 - accuracy: 0.4046 - val_loss: 1.0843 - val_accuracy: 0.3750
# Epoch 5/10
# 9/9 [==============================] - 13s 1s/step - loss: 1.0753 - accuracy: 0.4122 - val_loss: 1.1048 - val_accuracy: 0.2812
# Epoch 6/10
# 9/9 [==============================] - 14s 1s/step - loss: 1.0741 - accuracy: 0.4275 - val_loss: 1.1100 - val_accuracy: 0.2500
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Test'])
plt.show()

# %% [markdown]
# # **ADAGRAD  WITH DROPOUT**

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt


# Define the paths to the train and test directories
train_dir = '/content/drive/MyDrive/archive/training set'
test_dir = '/content/drive/MyDrive/archive/testing set'

# Set the image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 16

# Create an instance of the ImageDataGenerator for data augmentation and normalization
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   rotation_range=10,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# Load and preprocess the test data
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_width, img_height),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(train_generator.num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adagrad',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,
                    steps_per_epoch=train_generator.samples // batch_size,
                    epochs=10,
                    validation_data=test_generator,
                    validation_steps=test_generator.samples // batch_size)

# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.
# Epoch 1/10
# 9/9 [==============================] - 47s 5s/step - loss: 1.1637 - accuracy: 0.3893 - val_loss: 1.0959 - val_accuracy: 0.3125
# Epoch 2/10
# 9/9 [==============================] - 14s 2s/step - loss: 1.1159 - accuracy: 0.3206 - val_loss: 1.0848 - val_accuracy: 0.4688
# Epoch 3/10
# 9/9 [==============================] - 13s 2s/step - loss: 1.0963 - accuracy: 0.4046 - val_loss: 1.0955 - val_accuracy: 0.3750
# Epoch 4/10
# 9/9 [==============================] - 13s 1s/step - loss: 1.0566 - accuracy: 0.3819 - val_loss: 1.0802 - val_accuracy: 0.3125
# Epoch 5/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.0792 - accuracy: 0.3817 - val_loss: 1.0755 - val_accuracy: 0.4375
# Epoch 6/10
# 9/9 [==============================] - 14s 2s/step - loss: 1.0816 - accuracy: 0.3740 - val_loss: 1.0745 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Test'])
plt.show()

# %% [markdown]
# # **ADAGRAD WITHOUT DROPOUT**

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense,Dropout
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt


# Define the paths to the train and test directories
train_dir = '/content/drive/MyDrive/archive/training set'
test_dir = '/content/drive/MyDrive/archive/testing set'

# Set the image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 16

# Create an instance of the ImageDataGenerator for data augmentation and normalization
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   rotation_range=10,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_width, img_height),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

# Load and preprocess the test data
test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_width, img_height),
                                                  batch_size=batch_size,
                                                  class_mode='categorical')

# Build the CNN model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(train_generator.num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adagrad',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator,
                    steps_per_epoch=train_generator.samples // batch_size,
                    epochs=10,
                    validation_data=test_generator,
                    validation_steps=test_generator.samples // batch_size)

# Plot the accuracy graph
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Test'])
plt.show()
# Out:
# Found 147 images belonging to 3 classes.
# Found 42 images belonging to 3 classes.
# Epoch 1/10
# 9/9 [==============================] - 13s 1s/step - loss: 1.0786 - accuracy: 0.4275 - val_loss: 1.1514 - val_accuracy: 0.3125
# Epoch 2/10
# 9/9 [==============================] - 13s 2s/step - loss: 1.0827 - accuracy: 0.4198 - val_loss: 1.0909 - val_accuracy: 0.3438
# Epoch 3/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.0789 - accuracy: 0.4046 - val_loss: 1.0812 - val_accuracy: 0.3750
# Epoch 4/10
# 9/9 [==============================] - 14s 2s/step - loss: 1.0544 - accuracy: 0.4861 - val_loss: 1.0534 - val_accuracy: 0.5000
# Epoch 5/10
# 9/9 [==============================] - 12s 1s/step - loss: 1.0469 - accuracy: 0.5038 - val_loss: 1.0719 - val_accuracy: 0.5312
# Epoch 6/10
# 9/9 [==============================] - 10s 1s/step - loss: 1.0575 - accuracy: 0.4427 - val_loss: 1.0586 - val_accuracy: 0.5000
# Epoch 7/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.legend(['Train', 'Test'])
plt.show()
